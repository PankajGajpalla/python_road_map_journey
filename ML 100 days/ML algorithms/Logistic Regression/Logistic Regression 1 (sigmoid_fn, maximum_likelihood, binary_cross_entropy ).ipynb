# %% [markdown]
# ### push and pull
# * misclassified hai to line ko pull karna hai or correctly calssified hai to line ko push karna hai
# ![image.png](attachment:image.png)
# * the magnitude of  push and pull will be dependent on the distance of the point from the line
#
# * step:-  we will ask every point if its  correctly classifed or misclassified?
# * if correctly classified then push the line away
# * if incorrectly classified then pull the line
#
# ### pull
# * if missclassified point closer to the line then pull with less magnitude but if a misclassified point away from the line then pull with high magnitude
#
# ### push
# * similarly if a classified point closer to the line will push strongly and if far away then push weekly with less magnitude

# %% [markdown]
# ### to do this all we need to remove our step function and use a sigmoid function
#
# * the sigmoid function scale down any value (-inf < Z < inf) down to (0 < y < 1)
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)
# y_hat = sigmoid(sumation 0 to n WiXi)
#
# then yi - y_hat ....

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Loss Function | maximum Likelihood | Cross Entropy

# %% [markdown]
# * need to find a loss function or an error function for this problem
# ![image.png](attachment:image.png)

# %% [markdown]
# * which line is better?
# ![image.png](attachment:image.png)
# * the right side wala right!
# * what about in this one between this two line which is better?
# ![image-2.png](attachment:image-2.png)
#
# * not able to answer , to really know which is better we will prove it mathematically (probability)
#
# ### lets take an example
# * we have the probability of being red and green of all points
# ![image-3.png](attachment:image-3.png)
#
# ### calculating the maximum Likelihood
# * according to maximum likelihood we multiple all the probabiliity of the model and the model whos probability is greater is a better model
#
# * we will take the probability of that points color only like(if a point is green then will take its probability of being green only)
#
# ![image-4.png](attachment:image-4.png)

# %% [markdown]
# ### problem with this is
#
# * the product we are calculating is very less and if we take a really large data set then it will come very very less , so it will not be valid
#
# * to solve this problem we replace the product with sumation but that by taking log of each points probability..
# ![image.png](attachment:image.png)
#
# * then the other problem is taking a log of a small number like 0.
# 7, 0.4 or 0.1 it all gives a negative value so..
#
# * so we insted of adding we subtraact the log
# * maximum likelihood ka negative log ka summation is called cross entropy
# ### The summation of negative log of maximum likelihood is called Cross Entropy
# ![image-2.png](attachment:image-2.png)
#
# * in the case of calculating maximum likelihood we were trying to maximize it but in cross entropy we try to minimize it
# * this is because chote no. ka log bada hota hai and bade no. ka log chota hota hai...
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ### Creating a new formula to solve the probelm
#
# ## - yi log(yi_hat) - (1-yi)log(1-yi_hat)
#
# ![image.png](attachment:image.png)
# ### also called log-loss error
# ### or  binary cross entropy
# * this deals with both the red and greed point (put yi_hat only probability of green value as it will derive for red if its red...)

# %% [markdown]
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# * the problem is theres no closed form solution for this so we need to calculate it through gradient descent
